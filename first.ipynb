# %%
import numpy as np
import pandas as pd
import bs4

# %%
electriity_data = pd.read_csv("Datasets/electricity_access_percent.csv",skiprows=4)
electriity_data
# Out:
#      Country Name Country Code                           Indicator Name  \
# 0           Aruba          ABW  Access to electricity (% of population)
# 1     Afghanistan          AFG  Access to electricity (% of population)
# 2          Angola          AGO  Access to electricity (% of population)
# 3         Albania          ALB  Access to electricity (% of population)
# 4         Andorra          AND  Access to electricity (% of population)
# ..            ...          ...                                      ...
# 259        Kosovo          XKX  Access to electricity (% of population)
# 260   Yemen, Rep.          YEM  Access to electricity (% of population)
# 261  South Africa          ZAF  Access to electricity (% of population)
# 262        Zambia          ZMB  Access to electricity (% of population)
# 263      Zimbabwe          ZWE  Access to electricity (% of population)
#
#      Indicator Code  1960  1961  1962  1963  1964  1965  ...        2009  \
# ...

# %%
gdp_data = pd.read_csv("Datasets\gdp_data.csv",skiprows=4)
gdp_data
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\g'
# <>:1: SyntaxWarning: invalid escape sequence '\g'
# C:\Users\namra\AppData\Local\Temp\ipykernel_3356\53554986.py:1: SyntaxWarning: invalid escape sequence '\g'
#   gdp_data = pd.read_csv("Datasets\gdp_data.csv",skiprows=4)
#      Country Name Country Code     Indicator Name  Indicator Code  \
# 0           Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD
# 1     Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD
# 2          Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD
# 3         Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD
# 4         Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD
# ..            ...          ...                ...             ...
# 259        Kosovo          XKX  GDP (current US$)  NY.GDP.MKTP.CD
# 260   Yemen, Rep.          YEM  GDP (current US$)  NY.GDP.MKTP.CD
# 261  South Africa          ZAF  GDP (current US$)  NY.GDP.MKTP.CD
# ...

# %% [markdown]
# # mystry now working

# %%
population_c_data = pd.read_csv("Datasets\population_data.csv",skiprows=4)
population_c_data
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\namra\AppData\Local\Temp\ipykernel_3356\43132545.py:1: SyntaxWarning: invalid escape sequence '\p'
#   population_data = pd.read_csv("Datasets\population_data.csv",skiprows=4)
#      Country Name Country Code     Indicator Name Indicator Code        1960  \
# 0           Aruba          ABW  Population, total    SP.POP.TOTL     54211.0
# 1     Afghanistan          AFG  Population, total    SP.POP.TOTL   8996351.0
# 2          Angola          AGO  Population, total    SP.POP.TOTL   5643182.0
# 3         Albania          ALB  Population, total    SP.POP.TOTL   1608800.0
# 4         Andorra          AND  Population, total    SP.POP.TOTL     13411.0
# ..            ...          ...                ...            ...         ...
# 259        Kosovo          XKX  Population, total    SP.POP.TOTL    947000.0
# ...

# %%
import sqlite3

# Step 1: Connect to the 'population_data.db' file
connection = sqlite3.connect('Datasets\population_data.db')

# Step 2: Create a cursor object
cursor = connection.cursor()

# Step 3: Execute an SQL query to list all tables
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")

# Step 4: Fetch and print the table names
tables = cursor.fetchall()
print("Tables in the database:", tables)

query = "SELECT * FROM population_data;"  
population_d_data = pd.read_sql_query(query, connection)
population_d_data
# Out:
# Tables in the database: [('population_data',)]
# <>:4: SyntaxWarning: invalid escape sequence '\p'
# <>:4: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\namra\AppData\Local\Temp\ipykernel_3356\1371214332.py:4: SyntaxWarning: invalid escape sequence '\p'
#   connection = sqlite3.connect('Datasets\population_data.db')
#      index  Country_Name Country_Code     Indicator_Name Indicator_Code  \
# 0        0         Aruba          ABW  Population, total    SP.POP.TOTL
# 1        1   Afghanistan          AFG  Population, total    SP.POP.TOTL
# 2        2        Angola          AGO  Population, total    SP.POP.TOTL
# 3        3       Albania          ALB  Population, total    SP.POP.TOTL
# 4        4       Andorra          AND  Population, total    SP.POP.TOTL
# ..     ...           ...          ...                ...            ...
# 259    259        Kosovo          XKX  Population, total    SP.POP.TOTL
# 260    260   Yemen, Rep.          YEM  Population, total    SP.POP.TOTL
# ...

# %%
population_j_data = pd.read_json("Datasets\population_data.json")
population_j_data
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\namra\AppData\Local\Temp\ipykernel_3356\3982761488.py:1: SyntaxWarning: invalid escape sequence '\p'
#   population_j_data = pd.read_json("Datasets\population_data.json")
# C:\Users\namra\AppData\Local\Temp\ipykernel_3356\3982761488.py:1: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   population_j_data = pd.read_json("Datasets\population_data.json")
# ...

# %%
population_x_data = pd.read_xml(r"Datasets\population_data.xml",parser="etree")
print(population_x_data.head())
# Out:
# Empty DataFrame
# Columns: [record]
# Index: []

# %% [markdown]
# # population_data.xml not working

# %%
projects_data = pd.read_csv("Datasets\projects_data.csv")
projects_data
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\namra\AppData\Local\Temp\ipykernel_3356\2611289497.py:1: SyntaxWarning: invalid escape sequence '\p'
#   projects_data = pd.read_csv("Datasets\projects_data.csv")
# C:\Users\namra\AppData\Local\Temp\ipykernel_3356\2611289497.py:1: DtypeWarning: Columns (44) have mixed types. Specify dtype option on import or set low_memory=False.
#   projects_data = pd.read_csv("Datasets\projects_data.csv")
#             id                   regionname  \
# 0      P162228                        Other
# 1      P163962                       Africa
# 2      P167672                   South Asia
# 3      P158768                   South Asia
# 4      P161364                       Africa
# ...        ...                          ...
# 18243  P006578  Latin America and Caribbean
# 18244  P037451      Europe and Central Asia
# 18245  P037362      Europe and Central Asia
# ...

# %%
rural_pop_per = pd.read_csv("Datasets\rural_population_percent.csv",skiprows=4)
rural_pop_per
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 rural_pop_per = pd.read_csv("Datasets\rural_population_percent.csv",skiprows=4)
#       2 rural_pop_per
#
# ...
